# %%
# %pwd

# %%
import pandas as pd
import os
#from numpy import loadtxt


os.chdir('..')

# Read data into papers
papers = pd.read_csv('C:/Users/Elahe/Box/papers/SBP-BRIMS/Data/traditional_spambots_1/traditional_spambots_1_tweets.csv')
papers.head(20)

# No of rows
#print(len(papers))

# print(papers.count)
# papers.info()

# papers=open("C:/Users/lmadahali/Box/papers/self-representation/Data/social_honeypot/cleanedwithpreprocessor_content_polluters_tweets2.txt")
# print(data.read(1000))

# Remove the columns
# papers = papers.drop(columns=['id'], axis=1)
# Print out the first rows of papers
# papers.head(20)

# %%
#cleaning with preprocessor package in IDLE, good for urls and numbers
import preprocessor as p

input_file_name = "C:/Users/Elahe/Box/papers/SBP-BRIMS/Data/traditional_spambots_1/traditional_spambots_1_tweets.txt"
p.clean_file(input_file_name, options=[p.OPT.URL, p.OPT.MENTION, p.OPT.RESERVED,p.OPT.EMOJI, p.OPT.SMILEY, p.OPT.NUMBER])

# %%
import re
from wordcloud import STOPWORDS
import nltk



papers['paper_text_processed'] = papers['text'].map(lambda x: re.sub('[,\.!?]', '', x))
papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('@[A-Za-z0-9]+', '', x))
papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('[0-9\.]+', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('wwwwwww', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('mn', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('da', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('gt', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('ww', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('www', '', x))
papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('rt', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('oh', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('en', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('el', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('es', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('se', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].str.replace('ya', '')
# papers['paper_text_processed'] = papers['paper_text_processed'].str.replace(r'15', '')
# papers['paper_text_processed'] = papers['paper_text_processed'].str.replace('kiim', '')
# papers['paper_text_processed'] = papers['paper_text_processed'].str.replace('amp', '')
# papers['paper_text_processed'] = papers['paper_text_processed'].str.replace('to', '')
# papers['paper_text_processed'] = papers['paper_text_processed'].str.replace('2009', '')
# papers['paper_text_processed'] = papers['paper_text_processed'].str.replace('lol', '')
# papers['paper_text_processed'] = papers['paper_text_processed'].str.replace('will', '')
# papers['paper_text_processed'] = papers['paper_text_processed'].str.replace('be', '')
# papers['paper_text_processed'] = papers['paper_text_processed'].str.replace('want to', '')
# papers['paper_text_processed'] = papers['paper_text_processed'].str.replace('to go', '')

# Removing punctuation
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('[^\w\s]', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('got', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('amp', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('rt', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('dont', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('via', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('im', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('u', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('bt', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('going', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('bt', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('didnt', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('cant', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('yo', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('jst', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('yor', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('abot', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('like', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('one', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('people', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('p', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('ot', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('didnt', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('shold', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('rt', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('fck', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('didnt', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('ost', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('im', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('2009', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('it2009', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('da', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('bt', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('se', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('oh', '', x))
# papers['paper_text_processed'] = papers['paper_text_processed'].map(lambda x: re.sub('tho', '', x))




# papers['paper_text_processed'] = papers['paper_text_processed'].join(filter(lambda x: not x.isdigit(), x))

# papers['paper_text_processed'] = papers['paper_text_processed'].apply(lambda x: " ".join(x for x in x.split() if x not in x.isdigit()))





papers['paper_text_processed'] = papers['paper_text_processed'].apply(lambda x: " ".join(x.lower() for x in x.split()))


papers['paper_text_processed'].head(20)

# %%
#stopwords


from nltk.corpus import stopwords
stop=stopwords.words('english')
papers['paper_text_processed'] = papers['paper_text_processed'].apply(lambda x: " ".join(x.lower() for x in x.split() if x not in stop))



papers['paper_text_processed'].head(20)



# def remove_stopwords(text):
#     text= [word for word in text if word not in stopword]
#     return text

# papers['paper_text_processed'] = papers['paper_text_processed'].apply(lambda x: remove_stopwords(x))

# %%
# getting common word

freq=pd.Series(' '.join(papers['paper_text_processed']).split()).value_counts()[:20]
freq

# %%
# common word removal

freq=list(freq.index)

papers['paper_text_processed'] = papers['paper_text_processed'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))

papers['paper_text_processed'].head(20)

# %%
# getting rare word 

freq=pd.Series(' '.join(papers['paper_text_processed']).split()).value_counts()[-10:]
freq

# %%
# rare word removal

freq = list(freq.index)
papers['paper_text_processed'] = papers['paper_text_processed'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))

# %%
# Import the wordcloud library
from wordcloud import WordCloud

# Join the different processed titles together.
long_string = ','.join(list(papers['paper_text_processed'].values))

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()

# %%
#vectorizing for LDA

# Load the library with the CountVectorizer method
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline


# Helper function
def plot_10_most_common_words(count_data, count_vectorizer):
    import matplotlib.pyplot as plt
    words = count_vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:10]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 
    
    plt.figure(2, figsize=(15, 15/1.6180))
    plt.subplot(title='10 most common words')
    sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 2.5})
    sns.barplot(x_pos, counts, palette='husl')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.show()
    
    
# Initialise the count vectorizer with the English stop words
count_vectorizer = CountVectorizer(stop_words='english')


# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(papers['paper_text_processed'])


# Visualise the 10 most common words
plot_10_most_common_words(count_data, count_vectorizer)

# %%
import warnings
warnings.simplefilter("ignore", DeprecationWarning)

# load the LDA modek from sk-learn
from sklearn.decomposition import LatentDirichletAllocation as LDA

# Helper function
def print_topics(model, count_vectorizer, n_top_words):
    words=count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                       for i in topic.argsort() [:-n_top_words -1:-1]]))
        
# Tweak the two parameters below
number_topics=5
number_words=10

# Create and fit the LDA model
lda=LDA(n_components=number_topics, n_jobs=-1)
lda.fit(count_data)

# Print the topics found by the LDA model
print ("Topics found via LDA")
print_topics(lda, count_vectorizer, number_words)

# %%
# logistic regression with LDA
